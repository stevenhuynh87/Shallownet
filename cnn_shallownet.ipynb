# %%
#!pip install scikit-learn tensorflow imutils matplotlib numpy
#%pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in ./.venv/lib/python3.12/site-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in ./.venv/lib/python3.12/site-packages (from opencv-python) (2.0.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
# import các thư viện cần thiết
# Cài đặt: pip install tensorflow==2.7.0
# Cài đặt pip install keras==2.7.0
# Nếu dùng phiên bản cao hơn thì lệnh 4, 5 phải thay đổi code
# Đây là file chính của chương trình để tạo ra model

from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from preprocessing.imagetoarraypreprocessor import ImageToArrayPreprocessor
from preprocessing.simplepreprocessor import SimplePreprocessor
from datasets.simpledatasetloader import SimpleDatasetLoader
from conv.shallownet import ShallowNet
from tensorflow.keras.optimizers import SGD
from imutils import paths
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Bước 1. Chuẩn bị dữ liệu

# %%
# Bước 1. Chuẩn bị dữ liệu
# Khởi tạo tiền xử lý ảnh
sp = SimplePreprocessor(32, 32) # Thiết lập kích thước ảnh 32 x 32
iap = ImageToArrayPreprocessor() # Gọi hàm để chuyển ảnh sang mảng

print("[INFO] Importing images...")
imagePaths = list(paths.list_images("datasets")) # tạo danh sách đường dẫn đến các folder con của folder datasets
# # Nạp ảnh rồi chuyển mức xám của pixel trong vùng [0,1]
sdl = SimpleDatasetLoader(preprocessors=[sp, iap])
(data, labels) = sdl.load(imagePaths, verbose=500)
data = data.astype("float") / 255.0

# Chia tách dữ liệu vào 02 tập, training: 75% và testing: 25%
(trainX, testX, trainY, testY) = train_test_split(data, labels,test_size=0.25, random_state=42)

# Chuyển dữ liệu nhãn ở số nguyên vào biểu diễn dưới dạng vectors
trainY = LabelBinarizer().fit_transform(trainY)  # Nhãn tập dữ liệu train
testY = LabelBinarizer().fit_transform(testY)    # Nhãn tâp dữ liệu test
# Out:
# [INFO] Importing images...
# [INFO] Đã xử lý 500/3000
# [INFO] Đã xử lý 1000/3000
# [INFO] Đã xử lý 1500/3000
# [INFO] Đã xử lý 2000/3000
# [INFO] Đã xử lý 2500/3000
# [INFO] Đã xử lý 3000/3000

# %% [markdown]
# # Bước 2. Xây dựng cấu trúc model (mạng)

# %%
# Bước 2. Xây dựng cấu trúc model (mạng)
# Tạo bộ tối ưu hóa cho model (hàm tối ưu SGD)
opt = SGD(learning_rate=0.005)

# Tạo model (mạng), biên dịch model
print("[INFO] Creating model...")
model = ShallowNet.build(width=32, height=32, depth=3, classes=3) # class = 3 là model phn 3 lớp
model.compile(loss="categorical_crossentropy", optimizer=opt,metrics=["accuracy"])
# Out:
# [INFO] Creating model...

# %% [markdown]
# # Bước 3. train model (mạng)

# %%
# Bước 3. train model (mạng)
print("[INFO] Training model...")
#H = model.fit(trainX, trainY, validation_data=(testX, testY),batch_size=32, epochs=10, verbose=1)
H = model.fit(trainX, trainY, validation_split = 0.1, batch_size=32, epochs=100, verbose=1)

# lưu model với tên: model.hdf5
model.save("model.hdf5")
# Out:
# [INFO] Training model...
# Epoch 1/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8051 - loss: 0.5093 - val_accuracy: 0.6978 - val_loss: 0.7441
# Epoch 2/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8007 - loss: 0.5084 - val_accuracy: 0.6622 - val_loss: 0.8060
# Epoch 3/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8147 - loss: 0.4867 - val_accuracy: 0.6089 - val_loss: 0.7596
# Epoch 4/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.8099 - loss: 0.4857 - val_accuracy: 0.6756 - val_loss: 0.7412
# Epoch 5/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.
100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9200 - loss: 0.2701 - val_accuracy: 0.6489 - val_loss: 0.7865
# Epoch 74/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9236 - loss: 0.2578 - val_accuracy: 0.7022 - val_loss: 0.7574
# Epoch 75/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9280 - loss: 0.2599 - val_accuracy: 0.6800 - val_loss: 0.7614
# Epoch 76/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9293 - loss: 0.2459 - val_accuracy: 0.6489 - val_loss: 0.8530
# Epoch 77/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9221 - loss: 0.2485 - val_accuracy: 0.6756 - val_loss: 0.8239
# Epoch 78/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9249 - loss: 0.2535 - val_accuracy: 0.6800 - val_loss: 0.8146
# Epoch 79/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9331 - loss: 0.2429 - val_accuracy: 0.6533 - val_loss: 0.8315
# Epoch 80/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9431 - loss: 0.2326 - val_accuracy: 0.6889 - val_loss: 0.8370
# Epoch 81/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9226 - loss: 0.2509 - val_accuracy: 0.6444 - val_loss: 0.8172
# Epoch 82/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9534 - loss: 0.2182 - val_accuracy: 0.6311 - val_loss: 0.8412
# Epoch 83/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9378 - loss: 0.2325 - val_accuracy: 0.6844 - val_loss: 0.7874
# Epoch 84/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9370 - loss: 0.2320 - val_accuracy: 0.6000 - val_loss: 0.9160
# Epoch 85/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9357 - loss: 0.2316 - val_accuracy: 0.7111 - val_loss: 0.7908
# Epoch 86/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9372 - loss: 0.2275 - val_accuracy: 0.6533 - val_loss: 0.7961
# Epoch 87/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9421 - loss: 0.2234 - val_accuracy: 0.6533 - val_loss: 0.7907
# Epoch 88/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9417 - loss: 0.2177 - val_accuracy: 0.6844 - val_loss: 0.8049
# Epoch 89/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9485 - loss: 0.2179 - val_accuracy: 0.6533 - val_loss: 0.7942
# Epoch 90/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9451 - loss: 0.2247 - val_accuracy: 0.6622 - val_loss: 0.7938
# Epoch 91/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9451 - loss: 0.2121 - val_accuracy: 0.6933 - val_loss: 0.8260
# Epoch 92/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9346 - loss: 0.2400 - val_accuracy: 0.6622 - val_loss: 0.8132
# Epoch 93/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9435 - loss: 0.2228 - val_accuracy: 0.6711 - val_loss: 0.8050
# Epoch 94/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9444 - loss: 0.2084 - val_accuracy: 0.6667 - val_loss: 0.8162
# Epoch 95/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9395 - loss: 0.2229 - val_accuracy: 0.6622 - val_loss: 0.7997
# Epoch 96/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9392 - loss: 0.2131 - val_accuracy: 0.7067 - val_loss: 0.8239
# Epoch 97/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9475 - loss: 0.2177 - val_accuracy: 0.6711 - val_loss: 0.8075
# Epoch 98/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9477 - loss: 0.2131 - val_accuracy: 0.6311 - val_loss: 0.8910
# Epoch 99/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9485 - loss: 0.2133 - val_accuracy: 0.6622 - val_loss: 0.8486
# Epoch 100/100
# 64/64 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9540 - loss: 0.2117 - val_accuracy: 0.6622 - val_loss: 0.8315
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %% [markdown]
# # Bước 4. Đánh giá model (mạng)

# %%
# Bước 4. Đánh giá model (mạng)
print("[INFO] Evaluating model...")
predictions = model.predict(testX, batch_size=32)
print(classification_report(testY.argmax(axis=1),predictions.argmax(axis=1),target_names=["cat", "dog", "panda"]))

# Vẽ kết quả train: Biểu đồ hàm loss quá trình train và độ chính xác (accuracy)
plt.style.use("ggplot")
plt.figure()
plt.plot(np.arange(0, 100), H.history["loss"], label="Model loss")
plt.plot(np.arange(0, 100), H.history["val_loss"], label="Validation loss")
plt.plot(np.arange(0, 100), H.history["accuracy"], label="Model accuracy")
plt.plot(np.arange(0, 1000), H.history["val_accuracy"], label="Validation accuracy")
plt.title("Model loss and accuracy")
plt.xlabel("Epoch")
plt.ylabel("Loss/accuracy")
plt.legend()
plt.show()
